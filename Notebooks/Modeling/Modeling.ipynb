# %% [markdown]
# <img src="https://github.com/akthammomani/akthammomani/assets/67468718/8d1f93b4-2270-477b-bd76-f9ec1c075307" width="1700"/>

# %% [markdown]
# # Modeling:
#
# <center>
#     <img src="https://github.com/user-attachments/assets/da4034bd-1a59-4446-a110-370ba92425fb" alt="modeling">
# </center>
#
# * **Group 1:** Aktham Almomani, Victor Hsu and Yunus Tezcan
# * **Course:** Introduction to Artificial Intelligence (MS-AAI-501) / University Of San Diego
# * **Semester:** Summer 2024

# %% [markdown]
# ## **Introduction**<a id='Introduction'></a>
# [Contents](#Contents)
#
# In this notebook, we will be developing an advanced content-based recommendation system for recipes using various machine learning techniques. The goal is to recommend recipes based on the similarity of their ingredients, categories, diet types, and ratings. We will follow these key steps:
#
# * **Data Preprocessing:** Convert the high_level_ingredients list to a single string and combine relevant features into a single text column.
# * **TF-IDF Vectorization:** Transform the combined text features into numerical vectors.
# * **Dimensionality Reduction:** Use PCA to reduce the dimensionality of the TF-IDF vectors.
# * **Clustering:** Apply KMeans clustering to group similar recipes.
# * **Neural Network Training:** Train a neural network to predict the cluster of a recipe based on its features.
# * **Similarity Calculation:** Implement a function to find and return recipes similar to a given target recipe, weighting the similarity scores by ratings.

# %% [markdown]
# ## **Dataset**<a id='Dataset'></a>
# [Contents](#Contents)
#
# **[All recipes website](https://www.allrecipes.com/)** is a popular online platform known for its extensive collection of user-generated recipes. It is a go-to resource for home cooks and culinary enthusiasts, offering a diverse range of recipes across various cuisines and dietary preferences. The website features detailed recipe information, including ingredients, instructions, user ratings, and reviews, making it a comprehensive resource for anyone looking to explore new dishes or improve their cooking skills.
#
# For AI-Powered Recipe Recommender project, we will be using a dataset scraped from **[All recipes website](https://www.allrecipes.com/)**. This [dataset](https://github.com/shaansubbaiah/allrecipes-scraper/blob/main/export/scraped-07-05-21.csv), provides a wealth of information about a wide variety of recipes, which will be essential for building an effective recommendation system.
#
# **Key Features of the Dataset:**
# * Recipe Titles
# * Ingredients
# * Instructions
# * Ratings
# * Reviews
# * Preparation and Cooking Times
# * Nutritional information
#
# The dataset from **[All recipes website](https://www.allrecipes.com/)** is a rich resource for AI-Recipe Recommender Project. It contains comprehensive details about each recipe, including titles, ingredients, instructions, ratings, reviews, and nutritional information. Leveraging this data, this project can deliver personalized, relevant, and appealing recipe recommendations to users, enhancing their cooking experience and meeting their dietary preferences.

# %% [markdown]
# ## **Setup and preliminaries**<a id='Setup_and_preliminaries'></a>
# [Contents](#Contents)

# %% [markdown]
# ### **Import libraries**<a id='Import_libraries'></a>
# [Contents](#Contents)

# %%
#Let's import the necessary packages:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.metrics import precision_score, recall_score, ndcg_score
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **Importing dataset**<a id='Importing_dataset'></a>
# [Contents](#Contents)

# %%
#First, let's load the cleaned dataset "Data Wrangling output dataset":
df = pd.read_csv('all_recipes_final_df_v1.csv')

# %% [markdown]
# ## **Validating The Dataset**<a id='Validating_the_dataset'></a>
# [Contents](#Contents)

# %%
# Now, let's look at the top 5 rows of the df:
df.head()
# Out:
#                          name  \
# 0  Simple Macaroni and Cheese
# 1    Gourmet Mushroom Risotto
# 2              Dessert Crepes
# 3                 Pork Steaks
# 4            Chicken Parmesan
#
#                                                  url              category  \
# 0  https://www.allrecipes.com/recipe/238691/simpl...             main-dish
# 1  https://www.allrecipes.com/recipe/85389/gourme...             main-dish
# 2  https://www.allrecipes.com/recipe/19037/desser...  breakfast-and-brunch
# 3  https://www.allrecipes.com/recipe/70463/pork-s...      meat-and-poultry
# 4  https://www.allrecipes.com/recipe/223042/chick...         world-cuisine
#
#                                              summary  rating  rating_count  \
# 0  A very quick and easy fix to a tasty side-dish...    4.42           834
# 1  Authentic Italian-style risotto cooked the slo...    4.80          3388
# 2  Essential crepe recipe.  Sprinkle warm crepes ...    4.80          1156
# 3  My mom came up with this recipe when I was a c...    4.57           689
# 4  My version of chicken parmesan is a little dif...    4.83          4245
#
#    review_count                                        ingredients  \
# 0           575  1 (8 ounce) box elbow macaroni ; ¼ cup butter ...
# 1          2245  6 cups chicken broth, divided ; 3 tablespoons ...
# 2           794  4  eggs, lightly beaten ; 1 ⅓ cups milk ; 2 ta...
# 3           539  ¼ cup butter ; ¼ cup soy sauce ; 1 bunch green...
# 4          2662  4  skinless, boneless chicken breast halves ; ...
#
#                                           directions     prep     cook  \
# 0  Bring a large pot of lightly salted water to a...  10 mins  20 mins
# 1  In a saucepan, warm the broth over low heat. W...  20 mins  30 mins
# 2  In large bowl, whisk together eggs, milk, melt...  10 mins  10 mins
# 3  Melt butter in a skillet, and mix in the soy s...  15 mins  30 mins
# 4  Preheat an oven to 450 degrees F (230 degrees ...  25 mins  20 mins
#
#    servings  calories  carbohydrates_g  sugars_g  fat_g  saturated_fat_g  \
# 0         4     630.2             55.0       7.6   33.6             20.9
# 1         6     430.6             56.6       4.4   16.6              6.6
# 2         8     163.8             17.2       5.3    7.7              3.4
# 3         6     353.1              3.9       1.1   25.4             11.4
# 4         4     470.8             24.8       1.7   24.9              9.1
#
#    cholesterol_mg  protein_g  dietary_fiber_g  sodium_mg  calories_from_fat  \
# 0            99.6       26.5              2.1      777.0              302.2
# 1            29.3       11.3              2.7     1130.8              149.8
# 2           111.1        6.4              0.4      234.5               69.0
# 3           118.0       26.5              1.1      719.7              228.4
# 4           186.7       42.1              0.6      840.3              223.8
#
#    calcium_mg  iron_mg  magnesium_mg  potassium_mg  vitamin_a_iu_IU  \
# 0       567.9      2.7          61.8         380.0           1152.0
# 1        70.1      2.1          24.1         692.0            520.3
# 2        65.6      1.2          11.2         115.4            347.8
# 3        59.0      2.5          35.4         436.9            618.3
# 4       380.2      2.1          44.4         388.9            628.4
#
#    niacin_equivalents_mg  vitamin_c_mg  folate_mcg  thiamin_mg    total  \
# 0                   10.1           0.3       165.6         0.7  30 mins
# 1                    7.5           3.8        36.9         0.1  50 mins
# 2                    2.3           0.1        43.5         0.2  20 mins
# 3                    9.0           7.4        25.8         0.7  45 mins
# 4                   18.9           2.6        30.9         0.1  45 mins
#
#                                   parsed_ingredients  \
# 0  ['1 (8 ounce) box elbow macaroni', '¼ cup butt...
# 1  ['6 cups chicken broth, divided', '3 tablespoo...
# 2  ['4  eggs, lightly beaten', '1\u2009⅓ cups mil...
# 3  ['¼ cup butter', '¼ cup soy sauce', '1 bunch g...
# 4  ['4  skinless, boneless chicken breast halves'...
#
#                               high_level_ingredients  ingredient_count  \
# 0  ['all - purpose flour', 'salt', 'milk', 'elbow...                 7
# 1  ['chicken broth', 'shallots', 'Arborio rice', ...                12
# 2  ['all - purpose flour', 'milk', 'white sugar',...                 6
# 3  ['soy sauce', 'pork butt', 'bunch green onions...                 5
# 4  ['tomato sauce', 'fresh mozzarella', 'skinless...                13
#
#                            diet_type  carbohydrates_g_dv_perc  \
# 0                       High Protein                    20.00
# 1                          Low Sugar                    20.58
# 2                  Low Carb, Low Fat                     6.25
# 3  Low Carb, High Protein, Low Sugar                     1.42
# 4            High Protein, Low Sugar                     9.02
#
#    sugars_g_dv_perc  fat_g_dv_perc  saturated_fat_g_dv_perc  \
# 0              15.2          43.08                    104.5
# 1               8.8          21.28                     33.0
# 2              10.6           9.87                     17.0
# 3               2.2          32.56                     57.0
# 4               3.4          31.92                     45.5
#
#    cholesterol_mg_dv_perc  protein_g_dv_perc  dietary_fiber_g_dv_perc  \
# 0                   33.20               53.0                     7.50
# 1                    9.77               22.6                     9.64
# 2                   37.03               12.8                     1.43
# 3                   39.33               53.0                     3.93
# 4                   62.23               84.2                     2.14
#
#    sodium_mg_dv_perc  calcium_mg_dv_perc  iron_mg_dv_perc  \
# 0              33.78               43.68            15.00
# 1              49.17                5.39            11.67
# 2              10.20                5.05             6.67
# 3              31.29                4.54            13.89
# 4              36.53               29.25            11.67
#
#    magnesium_mg_dv_perc  potassium_mg_dv_perc  vitamin_a_iu_IU_dv_perc  \
# 0                 14.71                  8.09                    23.04
# 1                  5.74                 14.72                    10.41
# 2                  2.67                  2.46                     6.96
# 3                  8.43                  9.30                    12.37
# 4                 10.57                  8.27                    12.57
#
#    niacin_equivalents_mg_dv_perc  vitamin_c_mg_dv_perc  folate_mcg_dv_perc  \
# 0                          63.12                  0.33               41.40
# 1                          46.88                  4.22                9.22
# 2                          14.37                  0.11               10.88
# 3                          56.25                  8.22                6.45
# 4                         118.12                  2.89                7.72
#
#    thiamin_mg_dv_perc  calories_from_fat_dv_perc  recipe_length  \
# 0               58.33                      15.12             91
# 1                8.33                       7.47            147
# 2               16.67                       3.46             85
# 3               58.33                      11.43             56
# 4                8.33                      11.20            248
#
#    prep_time_mins  cook_time_mins  total_time_mins
# 0              10              20               30
# 1              20              30               50
# 2              10              10               20
# 3              15              30               45
# 4              25              20               45

# %%
#now, let's look at the shape of df:
shape = df.shape
print("Number of rows:", shape[0], "\nNumber of columns:", shape[1])
# Out:
# Number of rows: 27099
# Number of columns: 58

# %% [markdown]
# ## **Modeling - Advanced Content-Based Recommendation System**<a id='Modeling_Advanced_Content_Based_Recommendation_System'></a>
# [Contents](#Contents)
# In this modeling phase, we develop a recommendation system to suggest recipes based on user preferences and recipe similarities. The process involves several key techniques and steps to ensure accurate and relevant recommendations:
#
# ![model_architecture](https://github.com/user-attachments/assets/2d74c73f-5534-43f5-a126-fbb0c360aa0c)
#
# * **Data Preparation:**
#   * High-Level Ingredients: Convert the high_level_ingredients lists into strings for easier processing.
#   * Feature Combination: Combine category, diet type, and high-level ingredients into a single text column.
# * **TF-IDF Vectorization:**
#   * Purpose: Transform the combined text features into numerical vectors that represent the importance of each term in the dataset.
#   * Technique: Use the TF-IDF (Term Frequency-Inverse Document Frequency) vectorizer to create a matrix of features.
# * **Dimensionality Reduction:**
#   * Purpose: Reduce the complexity of the TF-IDF matrix while preserving essential information.
#   * Technique: Apply Principal Component Analysis (PCA) to reduce the TF-IDF matrix to 50 components.
# * **Clustering:**
#   * Purpose: Group similar recipes together to facilitate efficient and relevant recommendations.
#   * Technique: Use KMeans clustering to divide the dataset into 25 clusters based on the reduced feature set.
# * **Neural Network for Similarity Learning:**
#   * Purpose: Learn to predict the cluster membership of recipes, which helps in finding similar recipes.
#   * Architecture:
#     * Input Layer: 50-dimensional input corresponding to the PCA components.
#     * Hidden Layers: Two dense layers with 128 and 64 neurons, respectively, using ReLU activation.
#     * Output Layer: 25 output neurons with softmax activation to predict cluster probabilities.
#   * Compilation: The model is compiled using the Adam optimizer and categorical cross-entropy loss.
# * **Model Training:**
#   * Data: The PCA-transformed features are used as input (X), and the cluster labels are one-hot encoded as targets (y).
#   * Training: The model is trained over 25 epochs with a batch size of 32 and a validation split of 20%.
# * **Recipe Recommendation Function:**
#   * Purpose: Generate similar recipe recommendations based on a given recipe.
#   * Process:
#     * Find Target Cluster: Predict the cluster of the given recipe using the neural network.
#     * Calculate Similarities: Use cosine similarity to find recipes within the same cluster.
#     * Diversification (Optional): Adjust similarity scores to promote diversity in recommendations.
#     * Top Recommendations: Select the top N similar recipes, optionally diversified.
#
# This comprehensive approach ensures that the recommendation system is both accurate and efficient, providing users with relevant and varied recipe suggestions based on their preferences and the characteristics of the recipes in the dataset.

# %% [markdown]
# ### **Data Preprocessing**<a id='Data_Preprocessing'></a>
# [Contents](#Contents)

# %%
# Convert high_level_ingredients from list to a single string:
df['high_level_ingredients_str'] = df['high_level_ingredients'].apply(lambda x: ' '.join(eval(x)) if isinstance(x, str) else ' '.join(x))

# Combine relevant features into a single text column:
df['combined_features'] = df.apply(lambda row: f"{row['category']} {row['diet_type']} {row['high_level_ingredients_str']}", axis=1)

# %% [markdown]
# ### **TF-IDF Vectorization**<a id='TF_IDF_Vectorization'></a>
# [Contents](#Contents)

# %%
# TF-IDF vectorization:
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# %% [markdown]
# ### **Dimensionality Reduction Using PCA**<a id='Dimensionality_Reduction_Using_PCA'></a>
# [Contents](#Contents)

# %%
# Dimensionality reduction using PCA:
pca = PCA(n_components=50)
tfidf_pca = pca.fit_transform(tfidf_matrix.toarray())

# %% [markdown]
# ### **Clustering Using KMeans**<a id='Clustering_Using_KMeans'></a>
# [Contents](#Contents)

# %%
# Clustering using KMeans with 25 clusters:
kmeans = KMeans(n_clusters=25, random_state=42)
df['cluster'] = kmeans.fit_predict(tfidf_pca)
# Out:
# C:\Users\aktha\anaconda3\envs\tf_env\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ### **Neural Network for Learning Similarity**<a id='Neural_Network_for_Learning_Similarity'></a>
# [Contents](#Contents)

# %%
# Neural Network for learning similarity with 25 output neurons:
input_features = Input(shape=(50,))
dense1 = Dense(128, activation='relu')(input_features)
dense2 = Dense(64, activation='relu')(dense1)
output = Dense(25, activation='softmax')(dense2)
model = Model(inputs=input_features, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### **Train the Model**<a id='Train_the_Model'></a>
# [Contents](#Contents)

# %%
# Prepare the data for training:
X = tfidf_pca
y = tf.keras.utils.to_categorical(df['cluster'], num_classes=25)

# Train the model:
model.fit(X, y, epochs=25, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 678/678 [==============================] - 2s 2ms/step - loss: 1.0474 - accuracy: 0.7525 - val_loss: 0.3640 - val_accuracy: 0.8996
# Epoch 2/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.2287 - accuracy: 0.9319 - val_loss: 0.2314 - val_accuracy: 0.9225
# Epoch 3/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.1679 - accuracy: 0.9477 - val_loss: 0.1957 - val_accuracy: 0.9339
# Epoch 4/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.1385 - accuracy: 0.9544 - val_loss: 0.1767 - val_accuracy: 0.9360
# Epoch 5/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.1227 - accuracy: 0.9606 - val_loss: 0.1857 - val_accuracy: 0.9260
# Epoch 6/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.1092 - accuracy: 0.9636 - val_loss: 0.1571 - val_accuracy: 0.9376
# Epoch 7/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.1008 - accuracy: 0.9666 - val_loss: 0.1486 - val_accuracy: 0.9419
# Epoch 8/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0935 - accuracy: 0.9696 - val_loss: 0.1453 - val_accuracy: 0.9415
# Epoch 9/25
# 678/678 [==============================] - 1s 2ms/step - loss: 0.0867 - accuracy: 0.9701 - val_loss: 0.1457 - val_accuracy: 0.9437
# Epoch 10/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0811 - accuracy: 0.9722 - val_loss: 0.1599 - val_accuracy: 0.9356
# Epoch 11/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0755 - accuracy: 0.9743 - val_loss: 0.1444 - val_accuracy: 0.9413
# Epoch 12/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0724 - accuracy: 0.9750 - val_loss: 0.1362 - val_accuracy: 0.9443
# Epoch 13/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0690 - accuracy: 0.9769 - val_loss: 0.1292 - val_accuracy: 0.9487
# Epoch 14/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0655 - accuracy: 0.9774 - val_loss: 0.1378 - val_accuracy: 0.9450
# Epoch 15/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0631 - accuracy: 0.9780 - val_loss: 0.1394 - val_accuracy: 0.9456
# Epoch 16/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0597 - accuracy: 0.9789 - val_loss: 0.1380 - val_accuracy: 0.9450
# Epoch 17/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0575 - accuracy: 0.9800 - val_loss: 0.1297 - val_accuracy: 0.9483
# Epoch 18/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0560 - accuracy: 0.9808 - val_loss: 0.1332 - val_accuracy: 0.9470
# Epoch 19/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0527 - accuracy: 0.9825 - val_loss: 0.1268 - val_accuracy: 0.9476
# Epoch 20/25
# 678/678 [==============================] - 1s 2ms/step - loss: 0.0500 - accuracy: 0.9827 - val_loss: 0.1194 - val_accuracy: 0.9518
# Epoch 21/25
# 678/678 [==============================] - 1s 2ms/step - loss: 0.0479 - accuracy: 0.9841 - val_loss: 0.1284 - val_accuracy: 0.9489
# Epoch 22/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0456 - accuracy: 0.9848 - val_loss: 0.1658 - val_accuracy: 0.9389
# Epoch 23/25
# 678/678 [==============================] - 2s 2ms/step - loss: 0.0458 - accuracy: 0.9842 - val_loss: 0.1322 - val_accuracy: 0.9489
# Epoch 24/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0429 - accuracy: 0.9858 - val_loss: 0.1245 - val_accuracy: 0.9533
# Epoch 25/25
# 678/678 [==============================] - 2s 3ms/step - loss: 0.0424 - accuracy: 0.9857 - val_loss: 0.1506 - val_accuracy: 0.9423

# %% [markdown]
# ### **Function to Get Similar Recipes**<a id='Function_to_Get_Similar_Recipes'></a>
# [Contents](#Contents)

# %%
def get_similar_recipes(recipe_name, top_n=5, diversify=False, diversity_factor=0.1):
    target_index = df[df['name'] == recipe_name].index[0]
    target_features = tfidf_pca[target_index].reshape(1, -1)
    target_cluster = model.predict(target_features).argmax()
    cluster_indices = df[df['cluster'] == target_cluster].index
    similarities = cosine_similarity(target_features, tfidf_pca[cluster_indices]).flatten()
    weighted_similarities = similarities * df.loc[cluster_indices, 'rating']
    
    if diversify:
        # Diversify recommendations by adjusting the similarity scores
        diversified_scores = weighted_similarities * (1 - diversity_factor * np.arange(len(weighted_similarities)))
        similar_indices = cluster_indices[np.argsort(diversified_scores)[-top_n:][::-1]]
    else:
        similar_indices = cluster_indices[np.argsort(weighted_similarities)[-top_n:][::-1]]
    
    return df.iloc[similar_indices]

# %% [markdown]
# ### **Example Usage**<a id='Example Usage'></a>
# [Contents](#Contents)

# %%
#With Diversification:
similar_recipes_advanced = get_similar_recipes("Fluffy Pancakes", top_n=5, diversify=True, diversity_factor=0.2)
similar_recipes_advanced
# Out:
# 1/1 [==============================] - 0s 144ms/step
#                        name  \
# 2            Dessert Crepes
# 26  Joy's Easy Banana Bread
# 11          Classic Waffles
# 38          Fluffy Pancakes
# 61        Banana Pancakes I
#
#                                                   url              category  \
# 2   https://www.allrecipes.com/recipe/19037/desser...  breakfast-and-brunch
# 26  https://www.allrecipes.com/recipe/241707/joys-...  breakfast-and-brunch
# 11  https://www.allrecipes.com/recipe/20513/classi...  breakfast-and-brunch
# 38  https://www.allrecipes.com/recipe/162760/fluff...  breakfast-and-brunch
# 61  https://www.allrecipes.com/recipe/20334/banana...  breakfast-and-brunch
#
#                                               summary  rating  rating_count  \
# 2   Essential crepe recipe.  Sprinkle warm crepes ...    4.80          1156
# 26  This easy banana bread recipe is quick to prep...    4.80          2206
# 11   A lovely, crispy waffle perfect for the morning.    4.54          3738
# 38  Tall and fluffy.  These pancakes are just righ...    4.82         16778
# 61  Crowd pleasing banana pancakes made from scrat...    4.49          2558
#
#     review_count                                        ingredients  \
# 2            794  4  eggs, lightly beaten ; 1 ⅓ cups milk ; 2 ta...
# 26          1585  3  ripe bananas, mashed ; 1 cup white sugar ; ...
# 11          2636  2 cups all-purpose flour ; 1 teaspoon salt ; 4...
# 38         11851  ¾ cup milk ; 2 tablespoons white vinegar ; 1 c...
# 61          1899  1 cup all-purpose flour ; 1 tablespoon white s...
#
#                                            directions     prep     cook  \
# 2   In large bowl, whisk together eggs, milk, melt...  10 mins  10 mins
# 26  Preheat oven to 325 degrees F (165 degrees C)....  15 mins     1 hr
# 11  In a large bowl, mix together flour, salt, bak...  10 mins  15 mins
# 38  Combine milk with vinegar in a medium bowl and...  10 mins  10 mins
# 61  Combine flour, white sugar, baking powder and ...   5 mins  10 mins
#
#     servings  calories  carbohydrates_g  sugars_g  fat_g  saturated_fat_g  \
# 2          8     163.8             17.2       5.3    7.7              3.4
# 26        10     225.0             42.4      24.4    5.4              3.1
# 11         5     379.0             47.6       8.8   16.2              9.4
# 38         4     230.4             32.7       8.6    8.2              4.7
# 61         6     193.0             29.2       8.9    6.6              1.2
#
#     cholesterol_mg  protein_g  dietary_fiber_g  sodium_mg  calories_from_fat  \
# 2            111.1        6.4              0.4      234.5               69.0
# 26            30.8        3.0              1.4      398.8               48.6
# 11           112.8       10.2              1.4      899.1              145.8
# 38            65.4        6.4              0.8      649.6               73.9
# 61            34.3        5.0              1.6      245.9               59.7
#
#     calcium_mg  iron_mg  magnesium_mg  potassium_mg  vitamin_a_iu_IU  \
# 2         65.6      1.2          11.2         115.4            347.8
# 26         8.9      1.1          14.4         155.3            188.8
# 11       267.3      3.0          22.6         195.8            613.9
# 38       134.4      1.8          13.9         120.9            324.8
# 61       123.6      1.4          21.0         235.6            142.6
#
#     niacin_equivalents_mg  vitamin_c_mg  folate_mcg  thiamin_mg         total  \
# 2                     2.3           0.1        43.5         0.2       20 mins
# 26                    1.9           3.1        43.9         0.2  1 hr 15 mins
# 11                    5.1           0.1       105.0         0.4       25 mins
# 38                    3.2           0.1        65.6         0.3       20 mins
# 61                    2.5           3.5        51.9         0.2       15 mins
#
#                                    parsed_ingredients  \
# 2   ['4  eggs, lightly beaten', '1\u2009⅓ cups mil...
# 26  ['3  ripe bananas, mashed', '1 cup white sugar...
# 11  ['2 cups all-purpose flour', '1 teaspoon salt'...
# 38  ['¾ cup milk', '2 tablespoons white vinegar', ...
# 61  ['1 cup all-purpose flour', '1 tablespoon whit...
#
#                                high_level_ingredients  ingredient_count  \
# 2   ['all - purpose flour', 'milk', 'white sugar',...                 6
# 26  ['soda', 'all - purpose flour', 'white sugar',...                 7
# 11  ['powder', 'all - purpose flour', 'salt', 'whi...                 8
# 38  ['powder', 'soda', 'all - purpose flour', 'mil...                10
# 61  ['powder', 'all - purpose flour', 'white sugar...                 7
#
#             diet_type  carbohydrates_g_dv_perc  sugars_g_dv_perc  \
# 2   Low Carb, Low Fat                     6.25              10.6
# 26            Low Fat                    15.42              48.8
# 11            General                    17.31              17.6
# 38            Low Fat                    11.89              17.2
# 61            Low Fat                    10.62              17.8
#
#     fat_g_dv_perc  saturated_fat_g_dv_perc  cholesterol_mg_dv_perc  \
# 2            9.87                     17.0                   37.03
# 26           6.92                     15.5                   10.27
# 11          20.77                     47.0                   37.60
# 38          10.51                     23.5                   21.80
# 61           8.46                      6.0                   11.43
#
#     protein_g_dv_perc  dietary_fiber_g_dv_perc  sodium_mg_dv_perc  \
# 2                12.8                     1.43              10.20
# 26                6.0                     5.00              17.34
# 11               20.4                     5.00              39.09
# 38               12.8                     2.86              28.24
# 61               10.0                     5.71              10.69
#
#     calcium_mg_dv_perc  iron_mg_dv_perc  magnesium_mg_dv_perc  \
# 2                 5.05             6.67                  2.67
# 26                0.68             6.11                  3.43
# 11               20.56            16.67                  5.38
# 38               10.34            10.00                  3.31
# 61                9.51             7.78                  5.00
#
#     potassium_mg_dv_perc  vitamin_a_iu_IU_dv_perc  \
# 2                   2.46                     6.96
# 26                  3.30                     3.78
# 11                  4.17                    12.28
# 38                  2.57                     6.50
# 61                  5.01                     2.85
#
#     niacin_equivalents_mg_dv_perc  vitamin_c_mg_dv_perc  folate_mcg_dv_perc  \
# 2                           14.37                  0.11               10.88
# 26                          11.88                  3.44               10.98
# 11                          31.87                  0.11               26.25
# 38                          20.00                  0.11               16.40
# 61                          15.62                  3.89               12.98
#
#     thiamin_mg_dv_perc  calories_from_fat_dv_perc  recipe_length  \
# 2                16.67                       3.46             85
# 26               16.67                       2.43             75
# 11               33.33                       7.29             62
# 38               25.00                       3.69             91
# 61               16.67                       2.97             69
#
#     prep_time_mins  cook_time_mins  total_time_mins  \
# 2               10              10               20
# 26              15              60               75
# 11              10              15               25
# 38              10              10               20
# 61               5              10               15
#
#                            high_level_ingredients_str  \
# 2   all - purpose flour milk white sugar salt eggs...
# 26  soda all - purpose flour white sugar salt egg ...
# 11  powder all - purpose flour salt white sugar eg...
# 38  powder soda all - purpose flour milk white sug...
# 61  powder all - purpose flour white sugar salt mi...
#
#                                     combined_features  cluster
# 2   breakfast-and-brunch Low Carb, Low Fat all - p...       16
# 26  breakfast-and-brunch Low Fat soda all - purpos...       16
# 11  breakfast-and-brunch General powder all - purp...       16
# 38  breakfast-and-brunch Low Fat powder soda all -...       16
# 61  breakfast-and-brunch Low Fat powder all - purp...       16

# %%
#Without Diversification:
similar_recipes_advanced = get_similar_recipes("Fluffy Pancakes", top_n=5, diversify=True, diversity_factor=0)
similar_recipes_advanced
# Out:
# 1/1 [==============================] - 0s 36ms/step
#                                         name  \
# 38                           Fluffy Pancakes
# 2780           Fluffy and Delicious Pancakes
# 6749   Made from Scratch Blueberry Flapjacks
# 717                   Old-Fashioned Pancakes
# 19669                        Pancake Poppers
#
#                                                      url  \
# 38     https://www.allrecipes.com/recipe/162760/fluff...
# 2780   https://www.allrecipes.com/recipe/236165/fluff...
# 6749   https://www.allrecipes.com/recipe/260541/made-...
# 717    https://www.allrecipes.com/recipe/220415/old-f...
# 19669  https://www.allrecipes.com/recipe/255231/panca...
#
#                    category  \
# 38     breakfast-and-brunch
# 2780   breakfast-and-brunch
# 6749   breakfast-and-brunch
# 717    breakfast-and-brunch
# 19669  breakfast-and-brunch
#
#                                                  summary  rating  \
# 38     Tall and fluffy.  These pancakes are just righ...    4.82
# 2780   Tall, fluffy pancakes are delicious served wit...    4.71
# 6749   Delicious, easy and good for you! Blueberries ...    5.00
# 717    Anybody can add water to a boxed pancake mix, ...    4.56
# 19669  Pancakes didn't turn out so well on my electri...    4.42
#
#        rating_count  review_count  \
# 38            16778         11851
# 2780            421           300
# 6749              1             1
# 717            1030           775
# 19669            31            15
#
#                                              ingredients  \
# 38     ¾ cup milk ; 2 tablespoons white vinegar ; 1 c...
# 2780   ¾ cup milk ; 2 tablespoons white vinegar ; 1 c...
# 6749   1 cup all-purpose flour ; 1 teaspoon baking po...
# 717    1 ½ cups all-purpose flour ; 3 ½ teaspoons bak...
# 19669  1  serving cooking spray ; 1 ¼ cups milk ; ¼ c...
#
#                                               directions     prep     cook  \
# 38     Combine milk with vinegar in a medium bowl and...  10 mins  10 mins
# 2780   Stir milk and vinegar together in a bowl; set ...  15 mins  10 mins
# 6749   Whisk flour, baking powder, and salt together ...  10 mins   3 mins
# 717    Sift together flour, baking powder, salt, and ...   5 mins  20 mins
# 19669  Preheat oven to 375 degrees F (190 degrees C)....  10 mins   8 mins
#
#        servings  calories  carbohydrates_g  sugars_g  fat_g  saturated_fat_g  \
# 38            4     230.4             32.7       8.6    8.2              4.7
# 2780          4     235.6             33.5       8.7    8.2              4.7
# 6749          4     192.0             31.4       4.8    4.0              1.3
# 717           4     317.8             43.7       6.9   11.9              6.9
# 19669        24      61.4              7.7       2.7    2.8              0.6
#
#        cholesterol_mg  protein_g  dietary_fiber_g  sodium_mg  \
# 38               65.4        6.4              0.8      649.6
# 2780             65.4        6.4              1.3      648.8
# 6749             51.4        7.5              2.7      456.6
# 717              75.5        9.0              1.3     1119.1
# 19669             8.8        1.4              0.2      105.2
#
#        calories_from_fat  calcium_mg  iron_mg  magnesium_mg  potassium_mg  \
# 38                  73.9       134.4      1.8          13.9         120.9
# 2780                74.0       143.1      1.9          14.5         126.3
# 6749                36.3       175.2      2.3          19.4         161.9
# 717                107.2       342.3      2.9          21.5         184.8
# 19669               25.2        28.2      0.4           3.1          28.9
#
#        vitamin_a_iu_IU  niacin_equivalents_mg  vitamin_c_mg  folate_mcg  \
# 38               324.8                    3.2           0.1        65.6
# 2780             327.3                    3.2           0.1        65.6
# 6749             186.0                    4.0           2.5        71.5
# 717              471.1                    4.7           0.2        95.8
# 19669             34.2                    0.5           0.0        11.6
#
#        thiamin_mg    total                                 parsed_ingredients  \
# 38            0.3  20 mins  ['¾ cup milk', '2 tablespoons white vinegar', ...
# 2780          0.3  25 mins  ['¾ cup milk', '2 tablespoons white vinegar', ...
# 6749          0.3  13 mins  ['1 cup all-purpose flour', '1 teaspoon baking...
# 717           0.4  25 mins  ['1\u2009½ cups all-purpose flour', '3\u2009½ ...
# 19669         0.1  18 mins  ['1  serving cooking spray', '1\u2009¼ cups mi...
#
#                                   high_level_ingredients  ingredient_count  \
# 38     ['powder', 'soda', 'all - purpose flour', 'mil...                10
# 2780   ['powder', 'soda', 'all - purpose flour', 'mil...                12
# 6749   ['blueberries', 'powder', 'all - purpose flour...                 8
# 717    ['powder', 'all - purpose flour', 'salt', 'whi...                 8
# 19669  ['vinegar', 'powder', 'soda', 'all - purpose f...                10
#
#                                       diet_type  carbohydrates_g_dv_perc  \
# 38                                      Low Fat                    11.89
# 2780                                    Low Fat                    12.18
# 6749                         Low Fat, Low Sugar                    11.42
# 717                                     General                    15.89
# 19669  Low Carb, Low Fat, Low Sodium, Low Sugar                     2.80
#
#        sugars_g_dv_perc  fat_g_dv_perc  saturated_fat_g_dv_perc  \
# 38                 17.2          10.51                     23.5
# 2780               17.4          10.51                     23.5
# 6749                9.6           5.13                      6.5
# 717                13.8          15.26                     34.5
# 19669               5.4           3.59                      3.0
#
#        cholesterol_mg_dv_perc  protein_g_dv_perc  dietary_fiber_g_dv_perc  \
# 38                      21.80               12.8                     2.86
# 2780                    21.80               12.8                     4.64
# 6749                    17.13               15.0                     9.64
# 717                     25.17               18.0                     4.64
# 19669                    2.93                2.8                     0.71
#
#        sodium_mg_dv_perc  calcium_mg_dv_perc  iron_mg_dv_perc  \
# 38                 28.24               10.34            10.00
# 2780               28.21               11.01            10.56
# 6749               19.85               13.48            12.78
# 717                48.66               26.33            16.11
# 19669               4.57                2.17             2.22
#
#        magnesium_mg_dv_perc  potassium_mg_dv_perc  vitamin_a_iu_IU_dv_perc  \
# 38                     3.31                  2.57                     6.50
# 2780                   3.45                  2.69                     6.55
# 6749                   4.62                  3.44                     3.72
# 717                    5.12                  3.93                     9.42
# 19669                  0.74                  0.61                     0.68
#
#        niacin_equivalents_mg_dv_perc  vitamin_c_mg_dv_perc  \
# 38                             20.00                  0.11
# 2780                           20.00                  0.11
# 6749                           25.00                  2.78
# 717                            29.38                  0.22
# 19669                           3.12                  0.00
#
#        folate_mcg_dv_perc  thiamin_mg_dv_perc  calories_from_fat_dv_perc  \
# 38                  16.40               25.00                       3.69
# 2780                16.40               25.00                       3.69
# 6749                17.88               25.00                       1.80
# 717                 23.95               33.33                       5.36
# 19669                2.90                8.33                       1.26
#
#        recipe_length  prep_time_mins  cook_time_mins  total_time_mins  \
# 38                91              10              10               20
# 2780             109              15              10               25
# 6749              77              10               3               13
# 717               79               5              20               25
# 19669             94              10               8               18
#
#                               high_level_ingredients_str  \
# 38     powder soda all - purpose flour milk white sug...
# 2780   powder soda all - purpose flour milk white sug...
# 6749   blueberries powder all - purpose flour salt mi...
# 717    powder all - purpose flour salt white sugar eg...
# 19669  vinegar powder soda all - purpose flour milk w...
#
#                                        combined_features  cluster
# 38     breakfast-and-brunch Low Fat powder soda all -...       16
# 2780   breakfast-and-brunch Low Fat powder soda all -...       16
# 6749   breakfast-and-brunch Low Fat, Low Sugar bluebe...       16
# 717    breakfast-and-brunch General powder all - purp...       16
# 19669  breakfast-and-brunch Low Carb, Low Fat, Low So...       16

# %% [markdown]
# ### **Evaluation of the Recommendation System**<a id='Evaluation_of_the_Recommendation_System'></a>
# [Contents](#Contents)
#
# To ensure our recipe recommendation system is effective and meets user needs, we evaluate its performance using three key metrics: Precision, Recall, and Normalized Discounted Cumulative Gain (NDCG). These metrics help us measure the relevance, coverage, and ranking quality of the recommendations.
#
# **Metrics Used for Evaluation**
# * Precision:
#   * Definition: The proportion of recommended recipes that are relevant.
#   * Importance: Ensures users see mostly relevant recipes.
# * Recall:
#   * Definition: The proportion of all relevant recipes that are recommended.
#   * Importance: Ensures users do not miss out on relevant recipes.
# * NDCG (Normalized Discounted Cumulative Gain):
#   * Definition: Evaluates the ranking quality of the recommendations, emphasizing top-ranked relevant items.
#   * Importance: Ensures the most relevant recipes are presented first.
#
# **Techniques Used for Evaluation**
# * Cosine Similarity: Measures the similarity between recipes to identify the most similar ones to a given target recipe.
# * Diversification: Ensures recommendations are diverse by adjusting similarity scores to reduce the influence of very similar items.
# * Clustering: Groups similar recipes into clusters to facilitate finding and recommending similar recipes.
#
# **Evaluation Process**
# * Data Preparation: Split the dataset into training and testing sets.
# * Model Training: Train a neural network model to learn recipe similarities based on feature vectors.
# * Generating Recommendations: Predict clusters for test recipes, calculate cosine similarities within clusters, and apply diversification if enabled.
# Calculating Metrics:
#
# Compute Precision, Recall, and NDCG for the recommendations and average them across all test instances.
# The results are compiled into a DataFrame for easy visualization, summarizing the system's performance in relevance, coverage, and ranking quality.

# %%
# Evaluation function
def diversify_recommendations(similarities, top_indices, diversity_factor=0.1):
    # Reduce the influence of very similar items
    diversified_scores = similarities * (1 - diversity_factor * np.arange(len(similarities)))
    return np.argsort(diversified_scores)[-len(top_indices):][::-1]

def evaluate_recommendation_system(model, X_test, df, y_test_indices, top_n=5, diversity_factor=0.1):
    # Predict clusters for the test set
    predicted_clusters = model.predict(X_test)
    
    precision_scores = []
    recall_scores = []
    ndcg_scores = []
    
    for i, test_idx in enumerate(y_test_indices):
        target_features = X_test[i].reshape(1, -1)
        target_cluster = predicted_clusters[i].argmax()
        cluster_indices = df[df['cluster'] == target_cluster].index
        
        # Filter X_test to only include samples within cluster_indices
        cluster_test_indices = [idx for idx in cluster_indices if idx in y_test_indices]
        
        if not cluster_test_indices:
            continue
        
        test_indices_mapped = [np.where(y_test_indices == idx)[0][0] for idx in cluster_test_indices]
        similarities = cosine_similarity(target_features, X_test[test_indices_mapped]).flatten()
        top_indices = diversify_recommendations(similarities, test_indices_mapped, diversity_factor)
        
        # True labels for evaluation
        true_labels = (y_test[test_indices_mapped] == y_test[i]).astype(int)
        predicted_labels = np.zeros_like(true_labels)
        predicted_labels[top_indices] = 1
        
        # Precision and Recall
        precision = precision_score(true_labels, predicted_labels, zero_division=0)
        recall = recall_score(true_labels, predicted_labels, zero_division=0)
        
        precision_scores.append(precision)
        recall_scores.append(recall)
        
        # NDCG
        if np.any(true_labels):
            true_labels_ndcg = np.zeros(len(similarities))
            true_labels_ndcg[top_indices] = true_labels[top_indices]
            similarities_ndcg = np.zeros(len(similarities))
            similarities_ndcg[top_indices] = similarities[top_indices]
            ndcg = ndcg_score([true_labels_ndcg], [similarities_ndcg])
            ndcg_scores.append(ndcg)
    
    avg_precision = np.mean(precision_scores) * 100
    avg_recall = np.mean(recall_scores) * 100
    avg_ndcg = np.mean(ndcg_scores) * 100 if ndcg_scores else 0
    
    return round(avg_precision, 2), round(avg_recall, 2), round(avg_ndcg, 2)

# Split the data
X_train, X_test, y_train_indices, y_test_indices = train_test_split(tfidf_pca, df.index, test_size=0.2, random_state=42)
y_train = df.loc[y_train_indices, 'cluster'].values
y_test = df.loc[y_test_indices, 'cluster'].values

# Train the model on the training set
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=25)
model.fit(X_train, y_train_cat, epochs=25, batch_size=32, validation_split=0.2)

# Evaluate the model
avg_precision, avg_recall, avg_ndcg = evaluate_recommendation_system(model, X_test, df, y_test_indices)

# Create DataFrame to display results
results_df = pd.DataFrame({
    'Metric': ['Average Precision', 'Average Recall', 'Average NDCG'],
    'Score (%)': [avg_precision, avg_recall, avg_ndcg]
})
results_df
# Out:
# Epoch 1/25
# 542/542 [==============================] - 2s 3ms/step - loss: 0.0571 - accuracy: 0.9800 - val_loss: 0.0642 - val_accuracy: 0.9744
# Epoch 2/25
# 542/542 [==============================] - 1s 3ms/step - loss: 0.0480 - accuracy: 0.9828 - val_loss: 0.0621 - val_accuracy: 0.9786
# Epoch 3/25
# 542/542 [==============================] - 2s 3ms/step - loss: 0.0449 - accuracy: 0.9851 - val_loss: 0.0559 - val_accuracy: 0.9781
# Epoch 4/25
# 542/542 [==============================] - 1s 3ms/step - loss: 0.0407 - accuracy: 0.9871 - val_loss: 0.0635 - val_accuracy: 0.9739
# Epoch 5/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0383 - accuracy: 0.9875 - val_loss: 0.0731 - val_accuracy: 0.9702
# Epoch 6/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0392 - accuracy: 0.9865 - val_loss: 0.0665 - val_accuracy: 0.9714
# Epoch 7/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0365 - accuracy: 0.9885 - val_loss: 0.0662 - val_accuracy: 0.9742
# Epoch 8/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.0609 - val_accuracy: 0.9744
# Epoch 9/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.0691 - val_accuracy: 0.9737
# Epoch 10/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0330 - accuracy: 0.9897 - val_loss: 0.0768 - val_accuracy: 0.9696
# Epoch 11/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0312 - accuracy: 0.9903 - val_loss: 0.0687 - val_accuracy: 0.9719
# Epoch 12/25
# 542/542 [==============================] - 1s 3ms/step - loss: 0.0298 - accuracy: 0.9896 - val_loss: 0.0663 - val_accuracy: 0.9721
# Epoch 13/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 0.0677 - val_accuracy: 0.9693
# Epoch 14/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 0.0688 - val_accuracy: 0.9742
# Epoch 15/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0270 - accuracy: 0.9923 - val_loss: 0.0732 - val_accuracy: 0.9696
# Epoch 16/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0247 - accuracy: 0.9928 - val_loss: 0.0706 - val_accuracy: 0.9739
# Epoch 17/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 0.0708 - val_accuracy: 0.9714
# Epoch 18/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.0780 - val_accuracy: 0.9693
# Epoch 19/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 0.0757 - val_accuracy: 0.9684
# Epoch 20/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0226 - accuracy: 0.9938 - val_loss: 0.0741 - val_accuracy: 0.9700
# Epoch 21/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0214 - accuracy: 0.9942 - val_loss: 0.0827 - val_accuracy: 0.9714
# Epoch 22/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0770 - val_accuracy: 0.9705
# Epoch 23/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0786 - val_accuracy: 0.9679
# Epoch 24/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.9953 - val_loss: 0.0820 - val_accuracy: 0.9702
# Epoch 25/25
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.0881 - val_accuracy: 0.9673
# 170/170 [==============================] - 0s 1ms/step
#               Metric  Score (%)
# 0  Average Precision      96.92
# 1     Average Recall      96.92
# 2       Average NDCG     100.00

# %% [markdown]
# **Evaulation Summary Highlights:**
#
# * **Average Precision:** Of all the recipes recommended by the system, `96.92%` were relevant. This indicates a high level of accuracy in the recommendations provided, meaning users are likely to find the suggested recipes relevant to their interests.
# * **Average Recall:** The system was able to identify `96.92%` of all relevant recipes in the dataset. This high recall suggests that the recommendation system is comprehensive in retrieving almost all relevant items, ensuring users do not miss out on potentially interesting recipes.
# * **Average NDCG:** The Normalized Discounted Cumulative Gain (NDCG) score of `100.00%` indicates perfect ranking quality. This means that the most relevant recipes are consistently placed at the top of the recommendation list, enhancing user satisfaction by ensuring the best options are always presented first.
#
# **Overall Performance**
# * High Precision and Recall: The system demonstrates both high precision and high recall, indicating that it effectively identifies and recommends relevant recipes.
# * Perfect Ranking: The perfect NDCG score reflects the system's ability to rank the recommendations accurately, presenting the most relevant recipes first.
#
# These metrics suggest that the recommendation system is performing exceptionally well. Users are likely to experience highly relevant and well-ranked recipe recommendations, leading to a positive user experience.

# %% [markdown]
# ## **Saving Final Model**<a id='Saving_Final_Model'></a>
#
# [Contents](#Contents)
#
#
# Here, we'll be saving our advance content-based recommendation model:

# %%
import pickle
import gzip, pickletools

# %%
# Save the trained neural network model
with open('recipe_recommendation_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Save the PCA model
with open('pca_model.pkl', 'wb') as file:
    pickle.dump(pca, file)

# Save the TF-IDF vectorizer
with open('tfidf_vectorizer.pkl', 'wb') as file:
    pickle.dump(tfidf, file)

# %%
#Loading

# Load the trained neural network model
with open('recipe_recommendation_model.pkl', 'rb') as file:
    model = pickle.load(file)

# Load the PCA model
with open('pca_model.pkl', 'rb') as file:
    pca = pickle.load(file)

# Load the TF-IDF vectorizer
with open('tfidf_vectorizer.pkl', 'rb') as file:
    tfidf = pickle.load(file)
